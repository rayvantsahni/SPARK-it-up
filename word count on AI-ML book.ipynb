# %%
data = sc.textFile("/FileStore/tables/ai_ml_security_book.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;Security with AI and Machine Learning&#39;,
#  &#39;by Laurent Gil and Allan Liska&#39;,
#  &#39;Copyright � 2019 O�Reilly Media. All rights reserved.&#39;,
#  &#39;Printed in the United States of America.&#39;,
#  &#39;Published by O�Reilly Media, Inc., 1005 Gravenstein Highway North, Sebastopol, CA&#39;,
#  &#39;95472.&#39;,
#  &#39;O�Reilly books may be purchased for educational, business, or sales promotional use.&#39;,
#  &#39;Online editions are also available for most titles (http://oreilly.com). For more information,&#39;,
#  &#39;contact our corporate/institutional sales department: 800-998-9938 or corporate@&#39;,
#  &#39;oreilly.com.&#39;,
#  &#39;Editor: Virginia Wilson&#39;,
#  &#39;Production Editors: Nan Barber and&#39;,
#  &#39;Christopher Faucher&#39;,
#  &#39;Copyeditor: Octal Publishing, LLC&#39;,
#  &#39;Proofreader: Nan Barber&#39;]</div>

# %%
data_split = data.flatMap(lambda a: a.lower().split(" "))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_split.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: [&#39;security&#39;,
#  &#39;with&#39;,
#  &#39;ai&#39;,
#  &#39;and&#39;,
#  &#39;machine&#39;,
#  &#39;learning&#39;,
#  &#39;by&#39;,
#  &#39;laurent&#39;,
#  &#39;gil&#39;,
#  &#39;and&#39;]</div>

# %%
data_split.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 16877</div>

# %%
data_split_with_values = data_split.map(lambda w: (w, 1))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data_split_with_values.take(50)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: [(&#39;security&#39;, 1),
#  (&#39;with&#39;, 1),
#  (&#39;ai&#39;, 1),
#  (&#39;and&#39;, 1),
#  (&#39;machine&#39;, 1),
#  (&#39;learning&#39;, 1),
#  (&#39;by&#39;, 1),
#  (&#39;laurent&#39;, 1),
#  (&#39;gil&#39;, 1),
#  (&#39;and&#39;, 1),
#  (&#39;allan&#39;, 1),
#  (&#39;liska&#39;, 1),
#  (&#39;copyright&#39;, 1),
#  (&#39;�&#39;, 1),
#  (&#39;2019&#39;, 1),
#  (&#39;o�reilly&#39;, 1),
#  (&#39;media.&#39;, 1),
#  (&#39;all&#39;, 1),
#  (&#39;rights&#39;, 1),
#  (&#39;reserved.&#39;, 1),
#  (&#39;printed&#39;, 1),
#  (&#39;in&#39;, 1),
#  (&#39;the&#39;, 1),
#  (&#39;united&#39;, 1),
#  (&#39;states&#39;, 1),
#  (&#39;of&#39;, 1),
#  (&#39;america.&#39;, 1),
#  (&#39;published&#39;, 1),
#  (&#39;by&#39;, 1),
#  (&#39;o�reilly&#39;, 1),
#  (&#39;media,&#39;, 1),
#  (&#39;inc.,&#39;, 1),
#  (&#39;1005&#39;, 1),
#  (&#39;gravenstein&#39;, 1),
#  (&#39;highway&#39;, 1),
#  (&#39;north,&#39;, 1),
#  (&#39;sebastopol,&#39;, 1),
#  (&#39;ca&#39;, 1),
#  (&#39;95472.&#39;, 1),
#  (&#39;o�reilly&#39;, 1),
#  (&#39;books&#39;, 1),
#  (&#39;may&#39;, 1),
#  (&#39;be&#39;, 1),
#  (&#39;purchased&#39;, 1),
#  (&#39;for&#39;, 1),
#  (&#39;educational,&#39;, 1),
#  (&#39;business,&#39;, 1),
#  (&#39;or&#39;, 1),
#  (&#39;sales&#39;, 1),
#  (&#39;promotional&#39;, 1)]</div>

# %%
result_rdd = data_split_with_values.reduceByKey(lambda a,b: a+b)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_rdd.take(20)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [(&#39;security&#39;, 142),
#  (&#39;ai&#39;, 147),
#  (&#39;machine&#39;, 13),
#  (&#39;learning&#39;, 11),
#  (&#39;laurent&#39;, 5),
#  (&#39;gil&#39;, 2),
#  (&#39;allan&#39;, 4),
#  (&#39;liska&#39;, 2),
#  (&#39;copyright&#39;, 2),
#  (&#39;�&#39;, 16),
#  (&#39;2019&#39;, 1),
#  (&#39;o�reilly&#39;, 7),
#  (&#39;media.&#39;, 1),
#  (&#39;in&#39;, 265),
#  (&#39;united&#39;, 2),
#  (&#39;of&#39;, 508),
#  (&#39;published&#39;, 3),
#  (&#39;media,&#39;, 3),
#  (&#39;ca&#39;, 1),
#  (&#39;books&#39;, 1)]</div>

# %%
result_rdd_swap = result_rdd.map(lambda a: (a[1], a[0]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_rdd_swap.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [(142, &#39;security&#39;),
#  (147, &#39;ai&#39;),
#  (13, &#39;machine&#39;),
#  (11, &#39;learning&#39;),
#  (5, &#39;laurent&#39;),
#  (2, &#39;gil&#39;),
#  (4, &#39;allan&#39;),
#  (2, &#39;liska&#39;),
#  (2, &#39;copyright&#39;),
#  (16, &#39;�&#39;)]</div>

# %%
result_rdd_swap_sort_asc = result_rdd_swap.sortByKey()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_rdd_swap_sort_asc.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: [(1, &#39;2019&#39;),
#  (1, &#39;media.&#39;),
#  (1, &#39;ca&#39;),
#  (1, &#39;books&#39;),
#  (1, &#39;use.&#39;),
#  (1, &#39;titles&#39;),
#  (1, &#39;corporate/institutional&#39;),
#  (1, &#39;corporate@&#39;),
#  (1, &#39;oreilly.com.&#39;),
#  (1, &#39;virginia&#39;),
#  (1, &#39;wilson&#39;),
#  (1, &#39;production&#39;),
#  (1, &#39;editors:&#39;),
#  (1, &#39;publishing,&#39;),
#  (1, &#39;llc&#39;)]</div>

# %%
result_rdd_swap_sort_des = result_rdd_swap.sortByKey(ascending = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_rdd_swap_sort_des.take(15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: [(878, &#39;the&#39;),
#  (569, &#39;and&#39;),
#  (541, &#39;to&#39;),
#  (508, &#39;of&#39;),
#  (320, &#39;a&#39;),
#  (274, &#39;.&#39;),
#  (265, &#39;in&#39;),
#  (258, &#39;that&#39;),
#  (256, &#39;is&#39;),
#  (193, &#39;are&#39;),
#  (164, &#39;ml&#39;),
#  (152, &#39;for&#39;),
#  (147, &#39;ai&#39;),
#  (142, &#39;security&#39;),
#  (133, &#39;as&#39;)]</div>
